# %% [markdown]
# ## Python Packages
#
# Python Packages are the hearth of Python. Most python packages are open source and provide extensive functionalities that make python such a powerfurl programming and data analysis tool.
#
# If you installed anaconda, you should be good to go. There is no need for additional packages (for now). if you didn't, then you would need to install some packages yourself.
#
# To know what packages are available in your virtual environment (what is that!!). Simply type
#
# ```
# !pip freeze
# ```
#
# or
#
# ```
# conda list
#
# ```
#
# The commands will tell you the package name and version installed in your system.
#
# You can go to https://pypi.org/ to verify if you have the lastest version of a package.

# %%
# !pip freeze
# Out:
# alabaster @ file:///home/ktietz/src/ci/alabaster_1611921544520/work
# anaconda-client @ file:///C:/ci/anaconda-client_1624480273070/work
# anaconda-navigator==1.9.12
# anaconda-project @ file:///tmp/build/80754af9/anaconda-project_1626085644852/work
# appdirs==1.4.4
# argh==0.26.2
# argon2-cffi @ file:///C:/ci/argon2-cffi_1613037959010/work
# asn1crypto @ file:///tmp/build/80754af9/asn1crypto_1596577642040/work
# astroid @ file:///C:/ci/astroid_1628063293445/work
# astropy==4.0.1.post1
# async-generator @ file:///home/ktietz/src/ci/async_generator_1611927993394/work
# atomicwrites==1.4.0
# attrs @ file:///tmp/build/80754af9/attrs_1620827162558/work
# autopep8 @ file:///tmp/build/80754af9/autopep8_1592412889138/work
# Babel @ file:///tmp/build/80754af9/babel_1620871417480/work
# backcall @ file:///home/ktietz/src/ci/backcall_1611930011877/work
# backports.functools-lru-cache @ file:///tmp/build/80754af9/backports.functools_lru_cache_1618170165463/work
# ...

# %%
conda list
# Out:
# # packages in environment at C:\ProgramData\Anaconda3:
# #
# # Name                    Version                   Build  Channel
# _anaconda_depends         2020.07                  py38_0
# _ipyw_jlab_nb_ext_conf    0.1.0                    py38_0
# alabaster                 0.7.12             pyhd3eb1b0_0
# anaconda                  custom                   py38_1
# anaconda-client           1.8.0            py38haa95532_0
# anaconda-navigator        1.9.12                   py38_0
# anaconda-project          0.10.1             pyhd3eb1b0_0
# appdirs                   1.4.4                      py_0
# argh                      0.26.2                   py38_0
# argon2-cffi               20.1.0           py38h2bbff1b_1
# asn1crypto                1.4.0                      py_0
# astroid                   2.6.6            py38haa95532_0
# astropy                   4.0.1.post1      py38he774522_1
# async_generator           1.10               pyhd3eb1b0_0
#
# ...

# %% [markdown]
# Installing packages using pip (Package Installer for Python) or conda is straighforward (most times :-P)

# %%
# !pip install numpy

# %% [markdown]
# Here I'm trying to install the package **numpy** but it is already available in my system. To upgrade a package, you can use
# ```
# pip install <package_name> --upgrade
# ```

# %% [markdown]
# There are thousands of great Python packages available. If you find one interesting please share it in the forum
